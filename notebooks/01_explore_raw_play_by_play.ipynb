# %% [markdown]
# # Explore raw play-by-play data
# Load public CSVs, inspect columns, and understand coverage of key fields (personnel, motion, play action).

# %%
import pandas as pd
from conflict_map.data.load import load_raw_season

df = load_raw_season(2023)
df.head()
