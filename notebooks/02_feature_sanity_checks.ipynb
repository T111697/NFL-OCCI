# %% [markdown]
# # Feature sanity checks
# Validate engineered features like personnel parsing, motion flags, and target depth buckets.

# %%
import pandas as pd
from conflict_map.data.load import load_raw_season
from conflict_map.features.build_features import engineer_basic_features

df_raw = load_raw_season(2023)
df_feat = engineer_basic_features(df_raw)
df_feat[['personnel_group', 'has_motion', 'has_play_action', 'target_depth_bucket']].head()
