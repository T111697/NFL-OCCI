# %% [markdown]
# # OCCI validation
# Correlate OCCI with EPA, success rate, and explosive plays to understand signal strength.

# %%
import pandas as pd
from conflict_map.metrics.occi import compute_team_game_occi, compute_team_season_occi

# Load precomputed play-level conflict scores
df_conflict = pd.read_csv('data/processed/plays_with_conflict_scores.csv')
df_game = compute_team_game_occi(df_conflict)
df_season = compute_team_season_occi(df_game)
df_season.head()
